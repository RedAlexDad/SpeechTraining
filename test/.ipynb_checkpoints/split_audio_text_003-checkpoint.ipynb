# %%
import os
import librosa
import soundfile as sf
import speech_recognition as sr

# %%
def get_text_from_audio(file_path):
    recognizer = sr.Recognizer()

    with sr.AudioFile(file_path) as source:
        audio_data = recognizer.record(source)
        text = recognizer.recognize_google(audio_data, language="ru-RU")

    return text

# %%
def split_audio_by_silence(input_folder, output_folder, max_files=10):
    for root, dirs, files in os.walk(input_folder):
        for file in files:
            if file.endswith(".wav"):
                file_path = os.path.join(root, file)

                # Загрузка аудиофайла
                audio, sr = librosa.load(file_path, sr=16000)

                # Разделение на части по местам тишины
                intervals = librosa.effects.split(audio, top_db=20)

                # Извлечение текста из аудио
                full_text = get_text_from_audio(file_path)

                # Создание папки для результатов
                for word in full_text.split():
                    result_folder = os.path.join(output_folder, word)
                    os.makedirs(result_folder, exist_ok=True)

                    # Ограничение до max_files файлов, если указано
                    for i, (start, end) in enumerate(intervals[:max_files]):
                        audio_part = audio[start:end]
                        txt_file = os.path.join(result_folder, f"{word}.txt")
                        wav_file = os.path.join(result_folder, f"{word}.wav")

                        # Сохранение текста в файл
                        with open(txt_file, 'w') as txt:
                            txt.write(full_text)

                        # Сохранение аудиофайла
                        sf.write(wav_file, audio_part, sr)

# %%
# Замените пути к папкам на ваши
input_folder = "/home/redalexdad/recognition_speech/new_buriy_audiobooks_2_val"
output_folder = "/home/redalexdad/recognition_speech/voice_split"

# %%
split_audio_by_silence(input_folder, output_folder, max_files=10)
# Out:
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 split_audio_by_silence(input_folder, output_folder, max_files=10)
#
# Cell In[22], line 14, in split_audio_by_silence(input_folder, output_folder, max_files)
#      11 intervals = librosa.effects.split(audio, top_db=20)
#      13 # Извлечение текста из аудио
# ---> 14 full_text = get_text_from_audio(file_path)
#      16 # Создание папки для результатов
#      17 for word in full_text.split():
#
# Cell In[18], line 6, in get_text_from_audio(file_path)
#       4 with sr.AudioFile(file_path) as source:
#       5     audio_data = recognizer.record(source)
# ----> 6     text = recognizer.recognize_google(audio_data, language="ru-RU")
#       8 return text
#
# File ~/anaconda3/envs/dl_science/lib/python3.9/site-packages/speech_recognition/recognizers/google.py:251, in recognize_legacy(recognizer, audio_data, key, language, pfilter, show_all, with_confidence)
#     244 response_text = obtain_transcription(
#     245     request, timeout=recognizer.operation_timeout
#     246 )
#     248 output_parser = OutputParser(
#     249     show_all=show_all, with_confidence=with_confidence
#     250 )
# --> 251 return output_parser.parse(response_text)
#
# File ~/anaconda3/envs/dl_science/lib/python3.9/site-packages/speech_recognition/recognizers/google.py:124, in OutputParser.parse(self, response_text)
#     123 def parse(self, response_text: str):
# --> 124     actual_result = self.convert_to_result(response_text)
#     125     if self.show_all:
#     126         return actual_result
#
# File ~/anaconda3/envs/dl_science/lib/python3.9/site-packages/speech_recognition/recognizers/google.py:173, in OutputParser.convert_to_result(response_text)
#     171             raise UnknownValueError()
#     172         return result[0]
# --> 173 raise UnknownValueError()
#
# UnknownValueError:

# %%
from IPython import display
import matplotlib.pyplot as plt

# %%
data_dir = '/home/redalexdad/recognition_speech/voice_split'

# label_names = []
file_counter = 0  # Переменная для отслеживания количества обработанных файлов

# Рекурсивно обходим все файлы и подкаталоги в корневом каталоге
for root, dirs, files in os.walk(data_dir):
    for file in files:
        # Проверяем, что файл - звуковой файл
        if file.endswith(".wav"):
            # Увеличиваем счетчик обработанных файлов
            file_counter += 1

            # Проверяем, не превысило ли количество файлов 10
            if file_counter > 10:
                break

            # Остальной код вашего скрипта остается без изменений
            audio_file_path = os.path.join(root, file)
            label = os.path.basename(root)
            text_file_path = os.path.join(root, f"{os.path.splitext(file)[0]}.txt")

            if not os.path.exists(text_file_path):
                print(f"No text file found for {audio_file_path}")
                continue

            # Далее ваш код для чтения текста и вывода информации о звуке
            print(f"Label {label}")
            waveform, sample_rate = librosa.load(audio_file_path, sr=None)

            print("Audio shape:", waveform.shape)
            print('Waveform shape:', waveform.shape)
            # display(waveform)
            print('Audio playback')
            display.display(display.Audio(waveform, rate=sample_rate))

            plt.figure(figsize=(16, 3))
            plt.plot(waveform)
            plt.title(label)
            plt.yticks(np.arange(-1.2, 1.2, 0.2))
            plt.ylim([-1.1, 1.1])
            # Отображаем график после обработки
            plt.show()
# Out:
# Label ещё
# Audio shape: (6976,)
# Waveform shape: (6976,)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label воротам
# Audio shape: (35840,)
# Waveform shape: (35840,)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label мятежникам
# Audio shape: (13024,)
# Waveform shape: (13024,)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label чтобы
# Audio shape: (6656,)
# Waveform shape: (6656,)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label вечерним
# Audio shape: (5344,)
# Waveform shape: (5344,)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label у
# Audio shape: (8640,)
# Waveform shape: (8640,)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label туфли
# Audio shape: (6656,)
# Waveform shape: (6656,)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label на
# Audio shape: (11264,)
# Waveform shape: (11264,)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label красивое
# Audio shape: (6656,)
# Waveform shape: (6656,)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label тебе
# Audio shape: (6656,)
# Waveform shape: (6656,)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
